# %%
import pandas as pd

# %%
df = pd.read_csv("D:/KC\Master/2026/GFN 260/Intraday price prediction/Data/Processed/LVMH tick price 2024.csv", sep=';')

# %%
df['Trading Date Time'] = pd.to_datetime(df['Trading Date Time'])

# %%
df['Trading Date Time'] = pd.to_datetime(df['Trading Date Time'])

df = df.set_index('Trading Date Time')

# %%
df_5min = df.resample('5min').agg({ 'Price': 'last','Volume': 'sum'})
df_5min = df_5min.dropna()

# %%
df_5min.head()
# Out:
#                      Price  Volume
# Trading Date Time
# 2024-05-01 09:00:00  688.5   24407
# 2024-05-01 09:05:00  689.2    7217
# 2024-05-01 09:10:00  687.3    2788
# 2024-05-01 09:15:00  690.0    1257
# 2024-05-01 09:20:00  688.2    1808

# %%
import pandas as pd
df = pd.read_csv("D:/KC\Master/2026/GFN 260/Intraday price prediction/Data/Processed/LVMH tick price 2024.csv", sep=';')
df['Trading Date Time'] = pd.to_datetime(df['Trading Date Time'])
df['Trading Date Time'] = pd.to_datetime(df['Trading Date Time'])

df = df.set_index('Trading Date Time')
df_5min = df.resample('5min').agg({ 'Price': 'last','Volume': 'sum'})
df_5min = df_5min.dropna()
